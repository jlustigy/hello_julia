# %% [markdown]
# # Progamming in Julia
#
# You can [install Julia](http://julialang.org/downloads/) and get started in a [Jupyter notebook](http://quant-econ.net/jl/getting_started.html).

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# With the IJulia Jupyter notebook backend we can execute shell commands using the semicolon. For instance,

# %%
;ls
# Out:
# README.md
# getting_started.ipynb

# %%
;which julia
# Out:
# /Applications/Julia-0.4.5.app/Contents/Resources/julia/bin/julia

# %% [markdown]
# ### Install packages!

# %%
Pkg.add("DataFrames")
# Out:
# INFO: Cloning cache of ArrayViews from git://github.com/JuliaLang/ArrayViews.jl.git
# INFO: Cloning cache of DataArrays from git://github.com/JuliaStats/DataArrays.jl.git
# INFO: Cloning cache of DataFrames from git://github.com/JuliaStats/DataFrames.jl.git
# INFO: Cloning cache of Docile from git://github.com/MichaelHatherly/Docile.jl.git
# INFO: Cloning cache of GZip from git://github.com/JuliaLang/GZip.jl.git
# INFO: Cloning cache of Reexport from git://github.com/simonster/Reexport.jl.git
# INFO: Cloning cache of SortingAlgorithms from git://github.com/JuliaLang/SortingAlgorithms.jl.git
# INFO: Cloning cache of StatsBase from git://github.com/JuliaStats/StatsBase.jl.git
# INFO: Cloning cache of StatsFuns from git://github.com/JuliaStats/StatsFuns.jl.git
# INFO: Installing ArrayViews v0.6.4
# INFO: Installing DataArrays v0.2.20
# INFO: Installing DataFrames v0.7.0
# INFO: Installing Docile v0.5.23
# INFO: Installing GZip v0.2.18
# INFO: Installing Reexport v0.0.3
# INFO: Installing SortingAlgorithms v0.0.6
# INFO: Installing StatsBase v0.8.0
# INFO: Installing StatsFuns v0.2.0
# INFO: Package database updated

# %%
Pkg.add("PyPlot")
# Out:
# INFO: Cloning cache of ColorTypes from git://github.com/JuliaGraphics/ColorTypes.jl.git
# INFO: Cloning cache of Colors from git://github.com/JuliaGraphics/Colors.jl.git
# INFO: Cloning cache of Dates from git://github.com/quinnj/Dates.jl.git
# INFO: Cloning cache of FixedPointNumbers from git://github.com/JeffBezanson/FixedPointNumbers.jl.git
# INFO: Cloning cache of LaTeXStrings from git://github.com/stevengj/LaTeXStrings.jl.git
# INFO: Cloning cache of PyCall from git://github.com/stevengj/PyCall.jl.git
# INFO: Cloning cache of PyPlot from git://github.com/stevengj/PyPlot.jl.git
# INFO: Installing ColorTypes v0.2.1
# INFO: Installing Colors v0.6.3
# INFO: Installing Dates v0.4.4
# INFO: Installing FixedPointNumbers v0.1.2
# INFO: Installing LaTeXStrings v0.1.6
# INFO: Installing PyCall v1.4.0
# INFO: Installing PyPlot v2.1.1
# INFO: Building PyCall
# INFO: PyCall is using python (Python 2.7.11) at //anaconda/bin/python, libpython = //anaconda/lib/libpython2.7.dylib
# INFO: Package database updated

# %% [markdown]
# Check out the installed Julia packages

# %%
Pkg.status()
# Out:
# 2 required packages:
#  - DataFrames                    0.7.0
#  - IJulia                        1.1.8
# 17 additional packages:
#  - ArrayViews                    0.6.4
#  - BinDeps                       0.3.21
#  - Compat                        0.7.12
#  - Conda                         0.1.9
#  - DataArrays                    0.2.20
#  - Docile                        0.5.23
#  - GZip                          0.2.18
#  - Homebrew                      0.2.0
#  - JSON                          0.5.0
#  - Nettle                        0.2.2
#  - Reexport                      0.0.3
#  - SHA                           0.1.2
#  - SortingAlgorithms             0.0.6
#  - StatsBase                     0.8.0
#  - StatsFuns                     0.2.0
#  - URIParser                     0.1.3
#  - ZMQ                           0.3.1

# %% [markdown]
# You can update installed packages and also update local information on the set of available packages

# %%
Pkg.update()
# Out:
# INFO: Updating METADATA...
# INFO: Computing changes...
# INFO: No packages to install, update or remove

# %% [markdown]
# ### DataFrames

# %% [markdown]
# Pull the functionality from `DataFrames` into the current session

# %%
using DataFrames
# Out:
# INFO: Precompiling module DataFrames...

# %% [markdown]
# Now let’s use one of its functions to create a data frame object

# %%
df = DataFrame(x1=[1, 2], x2=["Luke", "Leia"])
# Out:
# 2x2 DataFrames.DataFrame
# │ Row │ x1 │ x2     │
# ┝━━━━━┿━━━━┿━━━━━━━━┥
# │ 1   │ 1  │ "Luke" │
# │ 2   │ 2  │ "Leia" │

# %% [markdown]
# ### For Loops

# %%
for i in 1:3
    println("i = $i")
end
# Out:
# i = 1
# i = 2
# i = 3

# %%
words = ["Luke", "Leia"]
for word in words
    println("Hello, $word")
end
# Out:
# Hello, Luke
# Hello, Leia

# %% [markdown]
# ### Plotting

# %%
using PyPlot
# Out:
# INFO: Precompiling module PyPlot...

# %%
# Set number of points 
n = 50

# Set random number seed
srand(1)

# Draw n random numbers
x = rand(n)
y = rand(n)

# Calulate a random area
area = pi .* (15 .* rand(n)).^2 # 0 to 15 point radii

# Plot
scatter(x, y, s=area, alpha=0.5)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31c166a90>)
# PyObject <matplotlib.collections.PathCollection object at 0x31b08e2d0>

# %%
ts_length = 100
# Draw numbers from normal distribution
epsilon_values = randn(ts_length)
plot(epsilon_values, "k-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31cc4b490>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31cea1690>

# %% [markdown]
# ### Arrays

# %%
typeof(epsilon_values)
# Out:
# Array{Float64,1}

# %%
epsilon_values
# Out:
# 100-element Array{Float64,1}:
#  -0.666459
#   1.91683
#   0.16946
#  -0.76297
#  -0.384447
#  -0.197554
#   1.0981
#   0.151374
#  -0.0221901
#   0.844892
#   0.10977
#  -0.559535
#  -0.59949
#   ⋮
#  -0.601307
#  -0.294389
#  -1.06878
#  -1.59072
#  -1.77476
#  -1.22891
#   0.359465
#   0.391476
#  -1.08961
#   1.68965
#   0.640137
#  -0.611969

# %%
x = [10, "Luke", false]
# Out:
# 3-element Array{Any,1}:
#     10
#       "Luke"
#  false

# %%
typeof(x)
# Out:
# Array{Any,1}

# %%
for i in 1:3
    xi = x[i]
    dx = typeof(x[i])
    print("Data Type of $xi = $dx \n")
end
# Out:
# Data Type of 10 = Int64
# Data Type of Luke = ASCIIString
# Data Type of false = Bool

# %%
length(x)
# Out:
# 3

# %%
pop!(x)
# Out:
# false

# %%
length(x)
# Out:
# 2

# %%
push!(x, "Leia")
# Out:
# 3-element Array{Any,1}:
#  10
#    "Luke"
#    "Leia"

# %%
ts_length = 100
n = 10
epsilon_values = Array(Float64, ts_length)
for i in 1:n
    epsilon_values = randn(ts_length)
    plot(epsilon_values)
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ddbd950>)

# %% [markdown]
# ### While Loops

# %%
ts_length = 100
epsilon_values = Array(Float64, ts_length)
i = 1
while i <= ts_length
    epsilon_values[i] = randn()
    i = i + 1
end
plot(epsilon_values, "og", alpha=0.5)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32006ff50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31d598410>

# %% [markdown]
# ### Functions

# %%
function generate_data(n)
    epsilon_values = Array(Float64, n)
    for i = 1:n
        epsilon_values[i] = randn()
    end
    return epsilon_values
end
# Out:
# generate_data (generic function with 1 method)

# %%
ts_length = 100
data1 = generate_data(ts_length)
data2 = generate_data(ts_length)
data3 = generate_data(ts_length)
plot(data1, "r-", ls="steps-mid")
plot(data2, "g-", ls="steps-mid")
plot(data3, "b-", ls="steps-mid")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320ffccd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31fef3890>
